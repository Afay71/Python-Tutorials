# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
numpyArray1 = np.linspace(0,10,20)          
numpyArray2 = numpyArray1 ** 2            
(myFigure, myAxes) = plt.subplots()                 
myAxes.plot(numpyArray1, numpyArray2, "g")   
myAxes.plot(numpyArray2, numpyArray1, "b")      
plt.show()

# %% [markdown]
# ###### 1)alpha: This parameter determines the opacity of the line or marker. It should be a decimal number between 0 and 1.0 means fully transparent, while 1 means fully opaque.
# ###### 2)linewidth: This parameter determines the thickness of the line. It can be a decimal or an integer value.
# ###### 3)linestyle: This parameter determines the style or pattern of the line. For example, "--" represents a dashed line.
# ###### 4)marker: This parameter determines the type of marker on the line. For example, "o" represents a dot.
# ###### 5)markersize: This parameter determines the size of the marker. It should be an integer value.
# ###### 6)markerfacecolor: This parameter determines the fill color of the marker. For example, "red" or HEX codes (#RRGGBB).

# %%
(myFigure, myAxes) = plt.subplots ()                                                                               #
myAxes.plot(numpyArray1, numpyArray2, "g", alpha=0.5)    # 1)  <---------------------------------------------------#
myAxes.plot(numpyArray2, numpyArray1, "b", linewidth=5.0) # 2) <---------------------------------------------------#
plt.show()                                                                                                         #
                                                                                                                   #
(newFigure, newAxes) = plt.subplots ()                                                                             #
newAxes.plot(numpyArray1, numpyArray1 + 4, color="green", linestyle = "-.") # 3) <---------------------------------# 
newAxes.plot(numpyArray1, numpyArray1 + 5, color="yellow", linestyle = ":")                                        #
newAxes.plot(numpyArray1, numpyArray1 + 6, color="blue", linestyle = "--")                                         #
                                                                            # 4)<-----------5)--------------6)-----#
newAxes.plot(numpyArray1, numpyArray1 + 7, color="#000000", linestyle = "--", marker = "o", markersize = 4, markerfacecolor="red")
newAxes.plot(numpyArray1, numpyArray1 + 8, color="#000000", linestyle = "--", marker = "+", markersize = 8, markerfacecolor="red")
plt.show()

# %% [markdown]
# ### SCATTER

# %%
plt.scatter(numpyArray1, numpyArray2)
plt.show()

# %% [markdown]
# ### HISTOGRAM

# %%
newArray = np.random.randint(0, 100, 50)
print(newArray)
plt.hist(newArray)
plt.show()
# Out:
# [11 21 94 92 62 16 52 52 71 20 15  4  2 52 58 47 16 11 15 97 43 41 56  9
#  17 15 49 68 28 70 23 40 98 81 53 34 58 23 38 16  1 47  9 89 62 57 42 29
#   1 27]

# %% [markdown]
# ### BOXPLOT

# %%
plt.boxplot(newArray)
plt.show()
